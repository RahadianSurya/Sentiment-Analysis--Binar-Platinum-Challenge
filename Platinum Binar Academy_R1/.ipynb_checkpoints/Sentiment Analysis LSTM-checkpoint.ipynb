# %%
import re
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from textblob import Word
import joblib

#Import library for tokeize, stemming, and stopwords
import nltk
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords as stopwords_scratch
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold

# Import library for Tensorflow Model Sentiment Analysis
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, SpatialDropout1D
from keras.layers import Embedding
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('data/train_preprocess.tsv', sep='\t', names=['Text', 'Sentiment'])
df.head()
# Out:
#                                                 Text Sentiment
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2  lokasi strategis di jalan sumatera bandung . t...  positive
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive
# 4  duh . jadi mahasiswa jangan sombong dong . kas...  negative

# %%
df['Sentiment'].value_counts().plot.bar(figsize= (7,4))
plt.title('Persebaran Sentiment Dalam Data Teks')
plt.xlabel('Sentiment')
plt.ylabel('Jumlah Kata')
plt.legend()
plt.show()

# %%
mapping = {
    'positive': 2,
    'neutral': 1,
    'negative': 0
}

df['label_val'] = df['Sentiment'].replace(mapping)
df['panjang_text'] = df['Text'].str.len()
df.head()
# Out:
#                                                 Text Sentiment  label_val  \
# 0  warung ini dimiliki oleh pengusaha pabrik tahu...  positive          2
# 1  mohon ulama lurus dan k212 mmbri hujjah partai...   neutral          1
# 2  lokasi strategis di jalan sumatera bandung . t...  positive          2
# 3  betapa bahagia nya diri ini saat unboxing pake...  positive          2
# 4  duh . jadi mahasiswa jangan sombong dong . kas...  negative          0
#
#    panjang_text
# 0           404
# 1           102
# 2           184
# 3            93
# 4           214

# %%
#visualisasi dengan box plot
import seaborn as sns
sns.set_style('whitegrid')
sns.boxplot(y = df['panjang_text'], x = df['Sentiment'])
plt.ylabel('Panjang Kata')
plt.title('Persebaran Data Sentiment')
plt.show()

# %%
#Pesebaran data dengan standar deviasi dan visualisasi
print(df['label_val'].describe(include=['all']))
# Out:
# count    11000.000000
# mean         1.270909
# std          0.906818
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: label_val, dtype: float64

# %%
print('Data Distribution')
print('mean: ', df['label_val'].mean())
print('variance: ', df['label_val'].var())
print('standar deviation: ', df['label_val'].std())
# Out:
# Data Distribution
# mean:  1.270909090909091
# variance:  0.822319384406795
# standar deviation:  0.9068182752937851

# %%
#kamus alay
df_alay = pd.read_csv('data/new_kamusalay.csv', names=['alay', 'cleaned'], encoding='latin-1')
df_alay.head()
# Out:
#                   alay                   cleaned
# 0  anakjakartaasikasik  anak jakarta asyik asyik
# 1         pakcikdahtua         pak cik sudah tua
# 2       pakcikmudalagi         pak cik muda lagi
# 3          t3tapjokowi              tetap jokowi
# 4                   3x                 tiga kali

# %%
#Create Stopwords
list_stopwords = stopwords_scratch.words('indonesian')
list_stopwords_en = stopwords_scratch.words('english')
list_stopwords.extend(list_stopwords_en)
list_stopwords.extend(['ya', 'yg', 'ga', 'yuk', 'dah', 'baiknya', 'berkali', 'kali', 'kurangnya', 'mata', 'olah', 'sekurang', 'setidak', 'tama', 'tidaknya'])

#External stopwords
f = open('stopwords/tala-stopwords-indonesia.txt', 'r')
stopword_external = []
for line in f:
    stripped_line = line.strip()
    line_list = stripped_line.split()
    stopword_external.append(line_list[0])
f.close()
list_stopwords.extend(stopword_external)

stopwords = list_stopwords

# %%
#Creating Function for Cleansing Process
def lowercase(text):
    return text.lower()

def special(text):
    text = re.sub(r'\W', ' ', str(text), flags=re.MULTILINE)
    return text

def single(text):
    text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text, flags=re.MULTILINE)
    return text

def singlestart(text):
    text = re.sub(r'\^[a-zA-Z]\s+', ' ', text, flags=re.MULTILINE)
    return text

def mulspace(text):
    text = re.sub(r'\s+', ' ', text, flags=re.MULTILINE)
    return text

#Removing RT
def rt(text):
    text = re.sub(r'rt @\w+: ', ' ', text, flags=re.MULTILINE)
    return text

#Removing prefixed 'b'
def prefixedb(text):
    text = re.sub(r'^b\s+', '', text, flags=re.MULTILINE)
    return text

def misc(text):
    text = re.sub(r'((www\.[^\s]+)|(https?://[^\s]+)|(http?://[^\s]+))|([#@]\S+)|user|\n|\t', ' ', text, flags=re.MULTILINE)
    return text

#Mapping for kamusalay
alay_mapping = dict(zip(df_alay['alay'], df_alay['cleaned']))
def alay(text):
    wordlist = text.split()
    text_alay = [alay_mapping.get(x,x) for x in wordlist]
    clean_alay = ' '.join(text_alay)
    return clean_alay

# Stopwords fuction
def stopwrds(text): 
    text_tokens = word_tokenize(text)
    tokens_without_sw = [word for word in text_tokens if not word in stopwords]
    output_sw = ' '.join(tokens_without_sw)
    return output_sw

#Function for text cleansing
def cleansing(text):
    text = lowercase(text)
    text = special(text)
    text = singlestart(text)
    text = mulspace(text)
    text = rt(text)
    text = prefixedb(text)
    text = misc(text)
    text = alay(text)
    text = stopwrds(text)
    return text

# %%
text = df['Text'].apply(lambda x: cleansing(x))
text
# Out:
# 0        warung dimiliki pengusaha pabrik puluhan terke...
# 1        mohon ulama lurus k212 mmbri hujjah partai diw...
# 2        lokasi strategis jalan sumatra bandung nya nya...
# 3        betapa bahagia nya unboxing paket barang nya b...
# 4        aduh mahasiswa sombong kasih kartu kuning bela...
#                                ...
# 10995                                               kecewa
# 10996    enak masakan nya kepiting menyenangkan memilih...
# 10997                     hormati partai partai berkoalisi
# 10998      pagi pagi tol pasteur macet parah bikin jengkel
# 10999    belanja yogyakarta riau junction lihat foodlif...
# Name: Text, Length: 11000, dtype: object

# %%
#Encoded the target column
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
df['Sentiment'] = lb.fit_transform(df['Sentiment'])
df['Sentiment']
# Out:
# 0        2
# 1        1
# 2        2
# 3        2
# 4        0
#         ..
# 10995    2
# 10996    2
# 10997    1
# 10998    0
# 10999    2
# Name: Sentiment, Length: 11000, dtype: int32

# %%
#Tokenizer
analisis = text.values
tokenizer = Tokenizer(num_words = 5000, split=' ')
tokenizer.fit_on_texts(analisis)
vocab_size = len(tokenizer.word_index) + 1
encoded_docs = tokenizer.texts_to_sequences(analisis)
x = pad_sequences(encoded_docs, maxlen=200)

# %%
#Dump Tokenizer
joblib.dump(tokenizer, 'tokenizer.pkl')
# Out:
# ['tokenizer.pkl']

# %%
print(tokenizer.word_index)
# Out:
# {'nya': 1, 'enak': 2, 'makanan': 3, 'makan': 4, 'harga': 5, 'menu': 6, 'bandung': 7, 'banget': 8, 'restoran': 9, 'suasana': 10, 'malam': 11, 'nyaman': 12, 'jalan': 13, 'orang': 14, 'pelayanan': 15, 'ayam': 16, 'goreng': 17, 'suka': 18, 'bagus': 19, 'pemandangan': 20, 'nasi': 21, 'teman': 22, 'indonesia': 23, 'pilihan': 24, 'mahal': 25, 'sih': 26, 'lumayan': 27, 'kota': 28, 'cocok': 29, 'keluarga': 30, 'pas': 31, 'lokasi': 32, 'resto': 33, 'anak': 34, 'pesan': 35, 'porsi': 36, 'salah': 37, 'steak': 38, 'sunda': 39, 'minuman': 40, 'kafe': 41, 'khas': 42, 'rumah': 43, 'murah': 44, 'masakan': 45, 'mi': 46, 'ramah': 47, 'ramai': 48, 'bakso': 49, 'sambal': 50, 'oke': 51, 'favorit': 52, 'jam': 53, 'deh': 54, 'bakar': 55, 'menikmati': 56, 'mantap': 57, '2': 58, 'siang': 59, 'coba': 60, 'terjangkau': 61, 'partai': 62, 'mencoba': 63, 'daging': 64, '1': 65, 'bikin': 66, 'masuk': 67, 'luas': 68, 'cepat': 69, 'daerah': 70, 'memesan': 71, 'pedas': 72, 'jokowi': 73, 'pakai': 74, 'unik': 75, 'batagor': 76, 'kopi': 77, 'sayang': 78, 'sesuai': 79, 'segar': 80, 'ikan': 81, 'indah': 82, 'pelayan': 83, 'parkir': 84, 'disajikan': 85, 'rekomendasi': 86, 'sate': 87, 'hotel': 88, 'duduk': 89, 'sejuk': 90, 'dicoba': 91, 'meja': 92, 'langsung': 93, 'standar': 94, 'bumbu': 95, 'terletak': 96, 'gue': 97, 'islam': 98, 'menunggu': 99, 'tersedia': 100, 'barat': 101, 'pengunjung': 102, 'romantis': 103, 'beli': 104, 'jakarta': 105, 'nongkrong': 106, 'udara': 107, 'presiden': 108, 'manis': 109, 'bersih': 110, 'dago': 111, 'ribu': 112, 'menarik': 113, 'es': 114, 'rakyat': 115, 'beragam': 116, 'area': 117, 'daun': 118, 'memilih': 119, 'warung': 120, 'dingin': 121, 'foto': 122, 'nama': 123, 'asyik': 124, 'kampung': 125, 'berkunjung': 126, 'negara': 127, 'ku': 128, 'marah': 129, 'saung': 130, 'pilih': 131, 'terkenal': 132, 'minum': 133, 'kasih': 134, '3': 135, 'mampir': 136, 'memiliki': 137, 'hati': 138, 'kecewa': 139, 'roti': 140, 'ditambah': 141, 'strategis': 142, 'lezat': 143, 'air': 144, 'braga': 145, 'kualitas': 146, 'zaman': 147, 'penuh': 148, 'kuah': 149, 'pizza': 150, 'buka': 151, 'konsep': 152, 'mencari': 153, 'pasangan': 154, 'kuliner': 155, 'lantai': 156, 'nikmat': 157, 'jawa': 158, 'cina': 159, 'mal': 160, 'terima': 161, 'chicken': 162, 'kue': 163, 'menyenangkan': 164, 'menyesal': 165, 'sore': 166, 'lengkap': 167, 'pokok': 168, 'teh': 169, 'lidah': 170, 'gubernur': 171, 'keren': 172, 'mengecewakan': 173, 'musik': 174, 'menyediakan': 175, 'mudah': 176, 'lampu': 177, 'demokrat': 178, 'jenis': 179, 'pagi': 180, 'senang': 181, 'indosat': 182, 'kemarin': 183, 'gurih': 184, 'menyajikan': 185, 'kayak': 186, 'bubur': 187, 'lupa': 188, 'rupiah': 189, 'keju': 190, 'babi': 191, 'paket': 192, '10': 193, 'lembang': 194, 'susah': 195, 'wajib': 196, 'barang': 197, 'ditawarkan': 198, 'minggu': 199, 'saus': 200, 'nih': 201, 'spesial': 202, 'kambing': 203, 'hidangan': 204, 'pesanan': 205, 'bosan': 206, 'berbeda': 207, 'otak': 208, 'ala': 209, 'alam': 210, 'cabang': 211, 'mie': 212, 'direkomendasikan': 213, 'beda': 214, 'panas': 215, 'terbaik': 216, 'selera': 217, 'empuk': 218, 'asin': 219, 'agama': 220, 'santai': 221, 'hehe': 222, 'tradisional': 223, 'macet': 224, 'kepiting': 225, 'kepala': 226, 'letak': 227, 'isi': 228, 'prabowo': 229, 'interior': 230, '000': 231, 'habis': 232, 'front': 233, 'puas': 234, 'pembela': 235, 'udang': 236, 'mengunjungi': 237, 'bebek': 238, 'utama': 239, 'bayar': 240, 'cari': 241, 'memuaskan': 242, 'bakmi': 243, 'pasta': 244, '5': 245, 'aneka': 246, 'relatif': 247, 'stroberi': 248, 'top': 249, 'istimewa': 250, 'variasi': 251, 'khusus': 252, '4': 253, 'ukuran': 254, 'kerja': 255, 'pusat': 256, 'bervariasi': 257, 'piring': 258, 'ruangan': 259, 'live': 260, 'muda': 261, 'sapi': 262, 'ringan': 263, 'desain': 264, 'bareng': 265, 'acara': 266, 'produk': 267, 'juara': 268, '30': 269, 'order': 270, 'mobil': 271, 'ulang': 272, 'sarapan': 273, 'telur': 274, 'indomie': 275, 'dasar': 276, 'demokrasi': 277, 'sop': 278, 'kursi': 279, 'asli': 280, 'kotor': 2 ...

# %%
#Evaluasi
embedding_vector_length = 32
model = Sequential()
model.add(Embedding(vocab_size, embedding_vector_length, input_length=200))
model.add(SpatialDropout1D(0.25))
model.add(LSTM(60, dropout=0.5, recurrent_dropout=0.5))
model.add(Dropout(0.2))
model.add(Dense(3, activation='softmax'))
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])  
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 32)           500576
#
#  spatial_dropout1d (SpatialD  (None, 200, 32)          0
#  ropout1D)
#
#  lstm (LSTM)                 (None, 60)                22320
#
#  dropout (Dropout)           (None, 60)                0
#
#  dense (Dense)               (None, 3)                 183
#
# =================================================================
# Total params: 523,079
# Trainable params: 523,079
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#training
from sklearn.model_selection import train_test_split

y = pd.get_dummies(df['Sentiment'])
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 42)

# %%
#callbacks
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > 0.95):
            print('\nAkurasi telah mencapai nilai >95%!')
            self.model.stop_training = True
callbacks = myCallback()

# %%
batch_size = 32
history = model.fit(X_train, y_train, epochs = 50, batch_size= batch_size, validation_split=0.3, callbacks=[callbacks])
# Out:
# Epoch 1/50
# 169/169 [==============================] - 39s 206ms/step - loss: 0.4682 - accuracy: 0.6712 - val_loss: 0.3609 - val_accuracy: 0.7675
# Epoch 2/50
# 169/169 [==============================] - 34s 199ms/step - loss: 0.3419 - accuracy: 0.7785 - val_loss: 0.3023 - val_accuracy: 0.7944
# Epoch 3/50
# 169/169 [==============================] - 34s 199ms/step - loss: 0.2727 - accuracy: 0.8284 - val_loss: 0.2505 - val_accuracy: 0.8377
# Epoch 4/50
# 169/169 [==============================] - 34s 199ms/step - loss: 0.2045 - accuracy: 0.8859 - val_loss: 0.2292 - val_accuracy: 0.8619
# Epoch 5/50
# 169/169 [==============================] - 36s 212ms/step - loss: 0.1584 - accuracy: 0.9087 - val_loss: 0.2361 - val_accuracy: 0.8589
# Epoch 6/50
# 169/169 [==============================] - 34s 202ms/step - loss: 0.1361 - accuracy: 0.9249 - val_loss: 0.2502 - val_accuracy: 0.8537
# Epoch 7/50
# 169/169 [==============================] - 34s 201ms/step - loss: 0.1147 - accuracy: 0.9327 - val_loss: 0.2647 - val_accuracy: 0.8519
# Epoch 8/50
# 169/169 [==============================] - 34s 200ms/step - loss: 0.1025 - accuracy: 0.9443 - val_loss: 0.2756 - val_accuracy: 0.8494
# Epoch 9/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9527
# Akurasi telah mencapai nilai >95%!
# 169/169 [==============================] - 34s 200ms/step - loss: 0.0884 - accuracy: 0.9527 - val_loss: 0.3004 - val_accuracy: 0.8463

# %%
model.evaluate(X_test, y_test)
# Out:
# 104/104 [==============================] - 3s 26ms/step - loss: 0.3337 - accuracy: 0.8345
# [0.33373895287513733, 0.8345454335212708]

# %%
model.save('model.h5')

# %%
#memvisualisasikan hasil prediksi dan hasil loss
plt.style.use('ggplot')

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc)+1)
    
    plt.figure(figsize=(12,5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label= 'Accuracy')
    plt.plot(x, val_acc, 'r', label='Validation Acc')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label= 'Loss')
    plt.plot(x, val_loss, 'r', label= 'Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

# %matplotlib inline
plot_history(history)

# %%
def predict_sentiment(text):
    sentiment_tf = ['negative', 'neutral', 'positive']
    text = cleansing(text)
    tos = tokenizer.texts_to_sequences([text])
    tos = pad_sequences(tos, maxlen=x.shape[1])
    prediction = model.predict(tos)
    polarity = np.argmax(prediction[0])
    return sentiment_tf[polarity]

# %%
output_tf = predict_sentiment('hai semuanya')
print(output_tf)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# neutral

# %%
y_test = y_test.values
y_pred = model.predict(X_test)
matrix_test = metrics.classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print(matrix_test)
# Out:
# 104/104 [==============================] - 3s 29ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77      1031
#            1       0.77      0.58      0.66       342
#            2       0.88      0.91      0.89      1927
#
#     accuracy                           0.83      3300
#    macro avg       0.81      0.76      0.78      3300
# weighted avg       0.83      0.83      0.83      3300

# %%
kf = KFold(n_splits=5, random_state=42, shuffle=True)
y = y.values
accuracies = []

for iteration, data in enumerate(kf.split(x), start=1):
    data_train = x[data[0]]
    target_train = y[data[0]]
    
    data_test = x[data[1]]
    target_test = y[data[1]]
    
    embedding_vector_length = 32
    model = Sequential()
    model.add(Embedding(vocab_size, embedding_vector_length, input_length=200))
    model.add(SpatialDropout1D(0.25))
    model.add(LSTM(60, dropout=0.5, recurrent_dropout=0.5))
    model.add(Dropout(0.2))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    batch_size = 32
    history = model.fit(X_train, y_train, epochs = 50, batch_size = batch_size, validation_split=0.3, callbacks=[callbacks])
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test.argmax(axis=1), y_pred.argmax(axis=1))
    
    print('Training no: ', iteration)
    print(metrics.classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
    print('==========================================================')
    
    accuracies.append(accuracy)

average_accuracy = np.mean(accuracies)

print()
print()
print()
print()
print('Average Accuracy: ', average_accuracy)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 38s 198ms/step - loss: 0.4859 - accuracy: 0.6482 - val_loss: 0.3567 - val_accuracy: 0.7636
# Epoch 2/50
# 169/169 [==============================] - 33s 197ms/step - loss: 0.3404 - accuracy: 0.7748 - val_loss: 0.2901 - val_accuracy: 0.7939
# Epoch 3/50
# 169/169 [==============================] - 34s 201ms/step - loss: 0.2540 - accuracy: 0.8436 - val_loss: 0.2453 - val_accuracy: 0.8377
# Epoch 4/50
# 169/169 [==============================] - 35s 205ms/step - loss: 0.1890 - accuracy: 0.8935 - val_loss: 0.2363 - val_accuracy: 0.8524
# Epoch 5/50
# 169/169 [==============================] - 34s 204ms/step - loss: 0.1529 - accuracy: 0.9117 - val_loss: 0.2368 - val_accuracy: 0.8563
# Epoch 6/50
# 169/169 [==============================] - 33s 197ms/step - loss: 0.1323 - accuracy: 0.9260 - val_loss: 0.2587 - val_accuracy: 0.8498
# Epoch 7/50
# 169/169 [==============================] - 34s 203ms/step - loss: 0.1103 - accuracy: 0.9410 - val_loss: 0.2753 - val_accuracy: 0.8472
# Epoch 8/50
# 169/169 [==============================] - 34s 202ms/step - loss: 0.0994 - accuracy: 0.9473 - val_loss: 0.2786 - val_accuracy: 0.8545
# Epoch 9/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0869 - accuracy: 0.9512
# Akurasi telah mencapai nilai >95%!
# 169/169 [==============================] - 35s 208ms/step - loss: 0.0869 - accuracy: 0.9512 - val_loss: 0.3094 - val_accuracy: 0.8459
# 104/104 [==============================] - 3s 27ms/step
# Training no:  1
#               precision    recall  f1-score   support
#
#            0       0.78      0.75      0.77      1031
#            1       0.66      0.68      0.67       342
#            2       0.88      0.90      0.89      1927
#
#     accuracy                           0.83      3300
#    macro avg       0.78      0.78      0.78      3300
# weighted avg       0.83      0.83      0.83      3300
#
# ==========================================================
# Epoch 1/50
# 169/169 [==============================] - 38s 199ms/step - loss: 0.4633 - accuracy: 0.6740 - val_loss: 0.3506 - val_accuracy: 0.7753
# Epoch 2/50
# 169/169 [==============================] - 33s 196ms/step - loss: 0.3439 - accuracy: 0.7725 - val_loss: 0.3120 - val_accuracy: 0.7922
# Epoch 3/50
# 169/169 [==============================] - 33s 197ms/step - loss: 0.2899 - accuracy: 0.8037 - val_loss: 0.2807 - val_accuracy: 0.8052
# Epoch 4/50
# 169/169 [==============================] - 36s 211ms/step - loss: 0.2272 - accuracy: 0.8581 - val_loss: 0.2481 - val_accuracy: 0.8351
# Epoch 5/50
# 169/169 [==============================] - 34s 201ms/step - loss: 0.1755 - accuracy: 0.9032 - val_loss: 0.2463 - val_accuracy: 0.8515
# Epoch 6/50
# 169/169 [==============================] - 33s 194ms/step - loss: 0.1474 - accuracy: 0.9204 - val_loss: 0.2698 - val_accuracy: 0.8446
# Epoch 7/50
# 169/169 [==============================] - 33s 195ms/step - loss: 0.1259 - accuracy: 0.9293 - val_loss: 0.2636 - val_accuracy: 0.8472
# Epoch 8/50
# 169/169 [==============================] - 34s 200ms/step - loss: 0.1056 - accuracy: 0.9408 - val_loss: 0.2807 - val_accuracy: 0.8468
# Epoch 9/50
# 169/169 [==============================] - 34s 199ms/step - loss: 0.0939 - accuracy: 0.9497 - val_loss: 0.2991 - val_accuracy: 0.8398
# Epoch 10/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9562
# Akurasi telah mencapai nilai >95%!
# 169/169 [==============================] - 36s 211ms/step - loss: 0.0828 - accuracy: 0.9562 - val_loss: 0.3081 - val_accuracy: 0.8416
# 104/104 [==============================] - 3s 27ms/step
# Training no:  2
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.76      1031
#            1       0.77      0.58      0.66       342
#            2       0.86      0.92      0.89      1927
#
#     accuracy                           0.83      3300
#    macro avg       0.80      0.74      0.77      3300
# weighted avg       0.82      0.83      0.82      3300
#
# ==========================================================
# Epoch 1/50
# 169/169 [==============================] - 38s 205ms/step - loss: 0.4775 - accuracy: 0.6662 - val_loss: 0.3578 - val_accuracy: 0.7697
# Epoch 2/50
# 169/169 [==============================] - 35s 207ms/step - loss: 0.3460 - accuracy: 0.7725 - val_loss: 0.3055 - val_accuracy: 0.7918
# Epoch 3/50
# 169/169 [==============================] - 35s 206ms/step - loss: 0.2813 - accuracy: 0.8174 - val_loss: 0.2602 - val_accuracy: 0.8216
# Epoch 4/50
# 169/169 [==============================] - 35s 206ms/step - loss: 0.2097 - accuracy: 0.8811 - val_loss: 0.2446 - val_accuracy: 0.8420
# Epoch 5/50
# 169/169 [==============================] - 36s 210ms/step - loss: 0.1699 - accuracy: 0.9030 - val_loss: 0.2472 - val_accuracy: 0.8455
# Epoch 6/50
# 169/169 [==============================] - 37s 220ms/step - loss: 0.1370 - accuracy: 0.9252 - val_loss: 0.2556 - val_accuracy: 0.8489
# Epoch 7/50
# 169/169 [==============================] - 38s 223ms/step - loss: 0.1214 - accuracy: 0.9327 - val_loss: 0.2724 - val_accuracy: 0.8442
# Epoch 8/50
# 169/169 [==============================] - 37s 217ms/step - loss: 0.1049 - accuracy: 0.9399 - val_loss: 0.2798 - val_accuracy: 0.8515
# Epoch 9/50
# 169/169 [==============================] - 37s 221ms/step - loss: 0.0949 - accuracy: 0.9464 - val_loss: 0.2975 - val_accuracy: 0.8485
# Epoch 10/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9555
# Akurasi telah mencapai nilai >95%!
# 169/169 [==============================] - 36s 211ms/step - loss: 0.0820 - accuracy: 0.9555 - val_loss: 0.3172 - val_accuracy: 0.8407
# 104/104 [==============================] - 3s 27ms/step
# Training no:  3
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77      1031
#            1       0.71      0.62      0.66       342
#            2       0.89      0.89      0.89      1927
#
#     accuracy                           0.83      3300
#    macro avg       0.78      0.77      0.77      3300
# weighted avg       0.83      0.83      0.83      3300
#
# ==========================================================
# Epoch 1/50
# 169/169 [==============================] - 38s 207ms/step - loss: 0.4662 - accuracy: 0.6746 - val_loss: 0.3503 - val_accuracy: 0.7667
# Epoch 2/50
# 169/169 [==============================] - 34s 204ms/step - loss: 0.3439 - accuracy: 0.7742 - val_loss: 0.3098 - val_accuracy: 0.7939
# Epoch 3/50
# 169/169 [==============================] - 35s 207ms/step - loss: 0.2891 - accuracy: 0.8069 - val_loss: 0.2713 - val_accuracy: 0.8173
# Epoch 4/50
# 169/169 [==============================] - 34s 204ms/step - loss: 0.2164 - accuracy: 0.8692 - val_loss: 0.2381 - val_accuracy: 0.8519
# Epoch 5/50
# 169/169 [==============================] - 35s 205ms/step - loss: 0.1662 - accuracy: 0.9065 - val_loss: 0.2511 - val_accuracy: 0.8403
# Epoch 6/50
# 169/169 [==============================] - 35s 205ms/step - loss: 0.1392 - accuracy: 0.9199 - val_loss: 0.2423 - val_accuracy: 0.8567
# Epoch 7/50
# 169/169 [==============================] - 35s 208ms/step - loss: 0.1229 - accuracy: 0.9334 - val_loss: 0.2653 - val_accuracy: 0.8481
# Epoch 8/50
# 169/169 [==============================] - 36s 213ms/step - loss: 0.0998 - accuracy: 0.9464 - val_loss: 0.2930 - val_accuracy: 0.8476
# Epoch 9/50
# 169/169 [==============================] - 35s 210ms/step - loss: 0.0883 - accuracy: 0.9490 - val_loss: 0.3155 - val_accuracy: 0.8429
# Epoch 10/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0796 - accuracy: 0.9553
# Akurasi telah mencapai nilai >95%!
# 169/169 [==============================] - 35s 209ms/step - loss: 0.0796 - accuracy: 0.9553 - val_loss: 0.3050 - val_accuracy: 0.8459
# 104/104 [==============================] - 3s 26ms/step
# Training no:  4
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77      1031
#            1       0.73      0.65      0.69       342
#            2       0.88      0.91      0.89      1927
#
#     accuracy                           0.83      3300
#    macro avg       0.80      0.77      0.78      3300
# weighted avg       0.83      0.83      0.83      3300
#
# ==========================================================
# Epoch 1/50
# 169/169 [==============================] - 43s 234ms/step - loss: 0.4726 - accuracy: 0.6681 - val_loss: 0.3541 - val_accuracy: 0.7697
# Epoch 2/50
# 169/169 [==============================] - 37s 217ms/step - loss: 0.3455 - accuracy: 0.7748 - val_loss: 0.3098 - val_accuracy: 0.7935
# Epoch 3/50
# 169/169 [==============================] - 34s 203ms/step - loss: 0.2843 - accuracy: 0.8160 - val_loss: 0.2620 - val_accuracy: 0.8216
# Epoch 4/50
# 169/169 [==============================] - 35s 208ms/step - loss: 0.2072 - accuracy: 0.8807 - val_loss: 0.2372 - val_accuracy: 0.8515
# Epoch 5/50
# 169/169 [==============================] - 35s 204ms/step - loss: 0.1674 - accuracy: 0.9048 - val_loss: 0.2400 - val_accuracy: 0.8524
# Epoch 6/50
# 169/169 [==============================] - 35s 207ms/step - loss: 0.1391 - accuracy: 0.9221 - val_loss: 0.2528 - val_accuracy: 0.8528
# Epoch 7/50
# 169/169 [==============================] - 34s 204ms/step - loss: 0.1179 - accuracy: 0.9351 - val_loss: 0.2607 - val_accuracy: 0.8528
# Epoch 8/50
# 169/169 [==============================] - 34s 200ms/step - loss: 0.1011 - accuracy: 0.9430 - val_loss: 0.2726 - val_accuracy: 0.8485
# Epoch 9/50
# 169/169 [==============================] - 35s 205ms/step - loss: 0.0918 - accuracy: 0.9464 - val_loss: 0.2892 - val_accuracy: 0.8411
# Epoch 10/50
# 169/169 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9549
# Akurasi telah mencapai nilai >95%!
# 169/169 [==============================] - 36s 214ms/step - loss: 0.0826 - accuracy: 0.9549 - val_loss: 0.3387 - val_accuracy: 0.8394
# 104/104 [==============================] - 3s 28ms/step
# Training no:  5
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76      1031
#            1       0.79      0.56      0.66       342
#            2       0.86      0.92      0.89      1927
#
#     accuracy                           0.83      3300
#    macro avg       0.81      0.74      0.77      3300
# weighted avg       0.83      0.83      0.82      3300
#
# ==========================================================
#
#
#
#
# Average Accuracy:  0.8296363636363635
